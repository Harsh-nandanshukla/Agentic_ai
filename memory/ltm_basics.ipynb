# %%
from langgraph.store.memory import InMemoryStore

# %%
#creating a store
store=InMemoryStore()

# %%
#creating a namesoace folder to store user specific memory
namespace=("user","u1")

# %%
store.put(namespace,"1",{"data":"User like to code in python"})
store.put(namespace,"2",{"data":"User goes to gym regularly and is on cut "})

# %%
namespace2=("user","u2")

# %%
store.put(namespace2,"1",{"data":"User like to code in C++"})
store.put(namespace2,"2",{"data":"User is mentally retarded "})

# %% [markdown]
# Retreiving Memories

# %%
store.get(namespace,"2")
# Out:
# Item(namespace=['user', 'u1'], key='2', value={'data': 'User goes to gym regularly and is on cut '}, created_at='2026-06-11T13:19:49.530240+00:00', updated_at='2026-06-11T13:19:49.530240+00:00')

# %%
store.get(namespace2,"1")
# Out:
# Item(namespace=['user', 'u2'], key='1', value={'data': 'User like to code in C++'}, created_at='2026-06-11T13:19:49.547050+00:00', updated_at='2026-06-11T13:19:49.547050+00:00')

# %%
items=store.search(namespace)
for item in items:
    print(item.value)
# Out:
# {'data': 'User like to code in python'}
# {'data': 'User goes to gym regularly and is on cut '}

# %%
items=store.search(namespace2)
for item in items:
    print(item.value)
# Out:
# {'data': 'User like to code in C++'}
# {'data': 'User is mentally retarded '}

# %% [markdown]
# SEMANTIC SEARCH

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding_model = OpenAIEmbeddings(model='text-embedding-3-small')

# %%
store = InMemoryStore(index={'embed': embedding_model, 'dims':1536})

# %%
namespace = ('users', 'u1')

# %%
store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items = store.search(namespace, query="what is the user currently learning", limit=1)

for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}

# %%
items = store.search(namespace, query="what are user's preferences", limit=3)

for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers dark mode in applications'}
# {'data': 'User prefers bullet points over paragraphs'}
# {'data': 'User prefers concise answers over long explanations'}
